# %% [markdown]
# # Aprendendo notebook
#
# Introdução ao uso de notebooks e da biblioteca pandas.

# %%
nome = 'Davi'

print(nome)
# Out:
# Davi

# %%
# Dicionarios python

aluno = {
    'nome': 'Davi',
    'matricula':'4654',
    'data_nascimento':'2006-01-12'
}

aluno2 = {
    'nome': 'Danilo',
    'matricula':'4893',
    'data_nascimento':'2004-09-10'
}

print(aluno)
print(aluno['nome'])
# Out:
# {'nome': 'Davi', 'matricula': '4654', 'data_nascimento': '2006-01-12'}
# <class 'dict'>
# Davi
# Danilo

# %%
alunos = [{
    'nome': 'Davi',
    'matricula':'4654',
    'data_nascimento':'2006-01-12'
},

{
    'nome': 'Danilo',
    'matricula':'4893',
    'data_nascimento':'2004-09-10'
}]

print(alunos[1]['nome'])
# Out:
# Danilo

# %%
frutas = [
    {
        'nomes':['uva', 'laranja','maca', 'abacaxi'],
        'quantidade':[10, 15, 100, 0],
        'valor':[10.45, 5.99, 7.43, 5]

    }
]

print(f'Fruta: {frutas[0]['nomes'][1]}, Quantidades: {frutas[0]['quantidade'][1]}, Valor:  {frutas[0]['valor'][1]}, ')
# Out:
# Fruta: laranja, Quantidades: 15, Valor:  5.99,

# %% [markdown]
# ## Instalando bibliotecas no python
#
# instala-se bibliotecas python usando a estrutura:
#
# `pip install nome_biblioteca`

# %%
! pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.4.4-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# ...
# Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl (9.7 MB)
# Using cached numpy-2.4.4-cp312-cp312-win_amd64.whl (12.3 MB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
import pandas as pd

# %%
frutas2 = ['uva', 'pera', 'maca']

frutas3 = pd.Series(['uva', 'pera', 'maca'])

print(type(frutas2))
print(type(frutas3))
# Out:
# <class 'list'>
# <class 'pandas.Series'>

# %%
display(frutas3)
# Out:
# 0     uva
# 1    pera
# 2    maca
# dtype: str

# %%
df = pd.DataFrame(
    {
        'nome':['uva', 'pera', 'maca'],
        'quantidade': [10,15,20],
        'valor':[5.99, 3.50, 1.50],
        'data':['2026-01-12', '2026-02-06', '2025-03-15']
    }
)

display(df)

# Criação de um DataFrame a partir de um dicionário
# Out:
#    nome  quantidade  valor        data
# 0   uva          10   5.99  2026-01-12
# 1  pera          15   3.50  2026-02-06
# 2  maca          20   1.50  2025-03-15

# %%
display(df['data'])

#forma de mostrar no console
# Out:
# 0    2026-01-12
# 1    2026-02-06
# 2    2025-03-15
# Name: data, dtype: str
